# %%
def getFuncName(i):
    if i==0:
        return "a"
    if i==1:
        return "F"
    if i==2:
        return "G"
    
def i2d(i):
    if i==0:
        return "0"
    if i==1:
        return "1"
    if i==2:
        return "2"
li = ""
for _f in range(3):
    for _t in range(3):
        for _r in range(3):
            for _theta in range(3):
                for _phi in range(3):
                    li += getFuncName(_f)+i2d(_t)+i2d(_r)+i2d(_theta)+i2d(_phi)+" "
var("L l_1 dt dr dtheta dphi l_2 "+li)
# Out:
# (L,
#  l_1,
#  dt,
#  dr,
#  dtheta,
#  dphi,
#  l_2,
#  a0000,
#  a0001,
#  a0002,
#  a0010,
#  a0011,
#  a0012,
#  a0020,
#  a0021,
#  a0022,
#  a0100,
#  a0101,
#  a0102,
#  a0110,
#  a0111,
#  a0112,
#  a0120,
#  a0121,
#  a0122,
#  a0200,
#  a0201,
#  a0202,
#  a0210,
#  a0211,
#  a0212,
#  a0220,
#  a0221,
#  a0222,
#  a1000,
#  a1001,
#  a1002,
#  a1010,
#  a1011,
#  a1012,
#  a1020,
#  a1021,
#  a1022,
#  a1100,
#  a1101,
#  a1102,
#  a1110,
#  a1111,
#  a1112,
#  a1120,
#  a1121,
#  a1122,
#  a1200,
#  a1201,
#  a1202,
#  a1210,
#  a1211,
#  a1212,
#  a1220,
#  a1221,
#  a1222,
#  a2000,
#  a2001,
#  a2002,
#  a2010,
#  a2011,
#  a2012,
#  a2020,
#  a2021,
#  a2022,
#  a2100,
#  a2101,
#  a2102,
#  a2110,
#  a2111,
#  a2112,
#  a2120,
#  a2121,
#  a2122,
#  a2200,
#  a2201,
#  a2202,
#  a2210,
#  a2211,
#  a2212,
#  a2220,
#  a2221,
#  a2222,
#  F0000,
#  F0001,
#  F0002,
#  F0010,
#  F0011,
#  F0012,
#  F0020,
#  F0021,
#  F0022,
#  F0100,
#  F0101,
#  F0102,
#  F0110,
# ...

# %%
for i in range(2):
    print("hola")
n1 = Function("\\nabla_\mu")
# Out:
# hola
# hola
# <>:3: DeprecationWarning: invalid escape sequence \m
# <>:3: DeprecationWarning: invalid escape sequence \m
# <ipython-input-20-5d5bcee7212a>:3: DeprecationWarning: invalid escape sequence \m
#   n1 = Function("\\nabla_\mu")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-5d5bcee7212a> in <module>
#       1 for i in range(Integer(2)):
#       2     print("hola")
# ----> 3 n1 = Function("\\nabla_\mu")
#
# NameError: name 'Function' is not defined

# %%
eq = L*(l_1*((1.0/2.0)*(-F1011 + F1211)*((1.0/8.0)*l_1*(-F1101 + F1121)*(a1001 - a1021 - a1201 + a1221)/(dr*pow(dtheta, 2)) + (1.0/8.0)*l_1*(-a1101 + a1121)*(F1001 - F1021 - F1201 + F1221)/(dr*pow(dtheta, 2)) - 1.0/8.0*(-F0111 + F2111)*(a0011 - a0211 - a2011 + a2211)/(dr*pow(dt, 2)) - 1.0/8.0*(-a0111 + a2111)*(F0011 - F0211 - F2011 + F2211)/(dr*pow(dt, 2)) + (1.0/2.0)*l_1*(-F1011 + F1211)*(a1011 - 2*a1111 + a1211)/pow(dr, 3) + (1.0/2.0)*l_1*(-a1011 + a1211)*(F1011 - 2*F1111 + F1211)/pow(dr, 3) + (1.0/8.0)*l_2*(-F1110 + F1112)*(a1010 - a1012 - a1210 + a1212)/(pow(dphi, 2)*dr) + (1.0/8.0)*l_2*(-a1110 + a1112)*(F1010 - F1012 - F1210 + F1212)/(pow(dphi, 2)*dr))*pow(sin(a1111), 2)/dr + (1.0/2.0)*(-F1011 + F1211)*(-a1011 + a1211)*((1.0/4.0)*l_1*(-F1101 + F1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-F0111 + F2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-F1011 + F1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-F1110 + F1112)*(-a1110 + a1112)/pow(dphi, 2))*sin(a1111)*cos(a1111)/pow(dr, 2) + (F1011 - 2*F1111 + F1211)*((1.0/4.0)*l_1*(-F1101 + F1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-F0111 + F2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-F1011 + F1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-F1110 + F1112)*(-a1110 + a1112)/pow(dphi, 2))*pow(sin(a1111), 2)/pow(dr, 2)) - l_1*((1.0/2.0)*(-a1011 + a1211)*((1.0/4.0)*l_1*(-F1101 + F1121)*(F1001 - F1021 - F1201 + F1221)/(dr*pow(dtheta, 2)) - 1.0/4.0*(-F0111 + F2111)*(F0011 - F0211 - F2011 + F2211)/(dr*pow(dt, 2)) + l_1*(-F1011 + F1211)*(F1011 - 2*F1111 + F1211)/pow(dr, 3) + (1.0/4.0)*l_2*(-F1110 + F1112)*(F1010 - F1012 - F1210 + F1212)/(pow(dphi, 2)*dr))*pow(sin(a1111), 2)/dr + (1.0/2.0)*pow(-a1011 + a1211, 2)*((1.0/4.0)*l_1*pow(-F1101 + F1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-F0111 + F2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-F1011 + F1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-F1110 + F1112, 2)/pow(dphi, 2))*sin(a1111)*cos(a1111)/pow(dr, 2) + (a1011 - 2*a1111 + a1211)*((1.0/4.0)*l_1*pow(-F1101 + F1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-F0111 + F2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-F1011 + F1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-F1110 + F1112, 2)/pow(dphi, 2))*pow(sin(a1111), 2)/pow(dr, 2)) + l_1*((1.0/2.0)*(-F1101 + F1121)*((1.0/2.0)*l_1*(-F1101 + F1121)*(a1101 - 2*a1111 + a1121)/pow(dtheta, 3) + (1.0/2.0)*l_1*(-a1101 + a1121)*(F1101 - 2*F1111 + F1121)/pow(dtheta, 3) - 1.0/8.0*(-F0111 + F2111)*(a0101 - a0121 - a2101 + a2121)/(pow(dt, 2)*dtheta) - 1.0/8.0*(-a0111 + a2111)*(F0101 - F0121 - F2101 + F2121)/(pow(dt, 2)*dtheta) + (1.0/8.0)*l_1*(-F1011 + F1211)*(a1001 - a1021 - a1201 + a1221)/(pow(dr, 2)*dtheta) + (1.0/8.0)*l_1*(-a1011 + a1211)*(F1001 - F1021 - F1201 + F1221)/(pow(dr, 2)*dtheta) + (1.0/8.0)*l_2*(-F1110 + F1112)*(a1100 - a1102 - a1120 + a1122)/(pow(dphi, 2)*dtheta) + (1.0/8.0)*l_2*(-a1110 + a1112)*(F1100 - F1102 - F1120 + F1122)/(pow(dphi, 2)*dtheta))*pow(sin(a1111), 2)/dtheta + (1.0/2.0)*(-F1101 + F1121)*(-a1101 + a1121)*((1.0/4.0)*l_1*(-F1101 + F1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-F0111 + F2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-F1011 + F1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-F1110 + F1112)*(-a1110 + a1112)/pow(dphi, 2))*sin(a1111)*cos(a1111)/pow(dtheta, 2) + (F1101 - 2*F1111 + F1121)*((1.0/4.0)*l_1*(-F1101 + F1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-F0111 + F2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-F1011 + F1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-F1110 + F1112)*(-a1110 + a1112)/pow(dphi, 2))*pow(sin(a1111), 2)/pow(dtheta, 2)) - l_1*((1.0/2.0)*(-a1101 + a1121)*(l_1*(-F1101 + F1121)*(F1101 - 2*F1111 + F1121)/pow(dtheta, 3) - 1.0/4.0*(-F0111 + F2111)*(F0101 - F0121 - F2101 + F2121)/(pow(dt, 2)*dtheta) + (1.0/4.0)*l_1*(-F1011 + F1211)*(F1001 - F1021 - F1201 + F1221)/(pow(dr, 2)*dtheta) + (1.0/4.0)*l_2*(-F1110 + F1112)*(F1100 - F1102 - F1120 + F1122)/(pow(dphi, 2)*dtheta))*pow(sin(a1111), 2)/dtheta + (1.0/2.0)*pow(-a1101 + a1121, 2)*((1.0/4.0)*l_1*pow(-F1101 + F1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-F0111 + F2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-F1011 + F1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-F1110 + F1112, 2)/pow(dphi, 2))*sin(a1111)*cos(a1111)/pow(dtheta, 2) + (a1101 - 2*a1111 + a1121)*((1.0/4.0)*l_1*pow(-F1101 + F1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-F0111 + F2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-F1011 + F1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-F1110 + F1112, 2)/pow(dphi, 2))*pow(sin(a1111), 2)/pow(dtheta, 2)) + l_1*((1.0/2.0)*(-G1011 + G1211)*((1.0/8.0)*l_1*(-G1101 + G1121)*(a1001 - a1021 - a1201 + a1221)/(dr*pow(dtheta, 2)) + (1.0/8.0)*l_1*(-a1101 + a1121)*(G1001 - G1021 - G1201 + G1221)/(dr*pow(dtheta, 2)) - 1.0/8.0*(-G0111 + G2111)*(a0011 - a0211 - a2011 + a2211)/(dr*pow(dt, 2)) - 1.0/8.0*(-a0111 + a2111)*(G0011 - G0211 - G2011 + G2211)/(dr*pow(dt, 2)) + (1.0/2.0)*l_1*(-G1011 + G1211)*(a1011 - 2*a1111 + a1211)/pow(dr, 3) + (1.0/2.0)*l_1*(-a1011 + a1211)*(G1011 - 2*G1111 + G1211)/pow(dr, 3) + (1.0/8.0)*l_2*(-G1110 + G1112)*(a1010 - a1012 - a1210 + a1212)/(pow(dphi, 2)*dr) + (1.0/8.0)*l_2*(-a1110 + a1112)*(G1010 - G1012 - G1210 + G1212)/(pow(dphi, 2)*dr))*pow(sin(F1111), 2)*pow(sin(a1111), 2)/dr + (1.0/2.0)*(-F1011 + F1211)*(-G1011 + G1211)*((1.0/4.0)*l_1*(-G1101 + G1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-G0111 + G2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-G1011 + G1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-G1110 + G1112)*(-a1110 + a1112)/pow(dphi, 2))*sin(F1111)*pow(sin(a1111), 2)*cos(F1111)/pow(dr, 2) + (1.0/2.0)*(-G1011 + G1211)*(-a1011 + a1211)*((1.0/4.0)*l_1*(-G1101 + G1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-G0111 + G2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-G1011 + G1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-G1110 + G1112)*(-a1110 + a1112)/pow(dphi, 2))*pow(sin(F1111), 2)*sin(a1111)*cos(a1111)/pow(dr, 2) + (G1011 - 2*G1111 + G1211)*((1.0/4.0)*l_1*(-G1101 + G1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-G0111 + G2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-G1011 + G1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-G1110 + G1112)*(-a1110 + a1112)/pow(dphi, 2))*pow(sin(F1111), 2)*pow(sin(a1111), 2)/pow(dr, 2)) - l_1*((1.0/2.0)*(-a1011 + a1211)*((1.0/4.0)*l_1*(-G1101 + G1121)*(G1001 - G1021 - G1201 + G1221)/(dr*pow(dtheta, 2)) - 1.0/4.0*(-G0111 + G2111)*(G0011 - G0211 - G2011 + G2211)/(dr*pow(dt, 2)) + l_1*(-G1011 + G1211)*(G1011 - 2*G1111 + G1211)/pow(dr, 3) + (1.0/4.0)*l_2*(-G1110 + G1112)*(G1010 - G1012 - G1210 + G1212)/(pow(dphi, 2)*dr))*pow(sin(F1111), 2)*pow(sin(a1111), 2)/dr + (1.0/2.0)*(-F1011 + F1211)*(-a1011 + a1211)*((1.0/4.0)*l_1*pow(-G1101 + G1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-G0111 + G2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-G1011 + G1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-G1110 + G1112, 2)/pow(dphi, 2))*sin(F1111)*pow(sin(a1111), 2)*cos(F1111)/pow(dr, 2) + (1.0/2.0)*pow(-a1011 + a1211, 2)*((1.0/4.0)*l_1*pow(-G1101 + G1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-G0111 + G2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-G1011 + G1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-G1110 + G1112, 2)/pow(dphi, 2))*pow(sin(F1111), 2)*sin(a1111)*cos(a1111)/pow(dr, 2) + (a1011 - 2*a1111 + a1211)*((1.0/4.0)*l_1*pow(-G1101 + G1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-G0111 + G2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-G1011 + G1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-G1110 + G1112, 2)/pow(dphi, 2))*pow(sin(F1111), 2)*pow(sin(a1111), 2)/pow(dr, 2)) + l_1*((1.0/2.0)*(-G1101 + G1121)*((1.0/2.0)*l_1*(-G1101 + G1121)*(a1101 - 2*a1111 + a1121)/pow(dtheta, 3) + (1.0/2.0)*l_1*(-a1101 + a1121)*(G1101 - 2*G1111 + G1121)/pow(dtheta, 3) - 1.0/8.0*(-G0111 + G2111)*(a0101 - a0121 - a2101 + a2121)/(pow(dt, 2)*dtheta) - 1.0/8.0*(-a0111 + a2111)*(G0101 - G0121 - G2101 + G2121)/(pow(dt, 2)*dtheta) + (1.0/8.0)*l_1*(-G1011 + G1211)*(a1001 - a1021 - a1201 + a1221)/(pow(dr, 2)*dtheta) + (1.0/8.0)*l_1*(-a1011 + a1211)*(G1001 - G1021 - G1201 + G1221)/(pow(dr, 2)*dtheta) + (1.0/8.0)*l_2*(-G1110 + G1112)*(a1100 - a1102 - a1120 + a1122)/(pow(dphi, 2)*dtheta) + (1.0/8.0)*l_2*(-a1110 + a1112)*(G1100 - G1102 - G1120 + G1122)/(pow(dphi, 2)*dtheta))*pow(sin(F1111), 2)*pow(sin(a1111), 2)/dtheta + (1.0/2.0)*(-F1101 + F1121)*(-G1101 + G1121)*((1.0/4.0)*l_1*(-G1101 + G1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-G0111 + G2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-G1011 + G1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-G1110 + G1112)*(-a1110 + a1112)/pow(dphi, 2))*sin(F1111)*pow(sin(a1111), 2)*cos(F1111)/pow(dtheta, 2) + (1.0/2.0)*(-G1101 + G1121)*(-a1101 + a1121)*((1.0/4.0)*l_1*(-G1101 + G1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-G0111 + G2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-G1011 + G1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-G1110 + G1112)*(-a1110 + a1112)/pow(dphi, 2))*pow(sin(F1111), 2)*sin(a1111)*cos(a1111)/pow(dtheta, 2) + (G1101 - 2*G1111 + G1121)*((1.0/4.0)*l_1*(-G1101 + G1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-G0111 + G2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-G1011 + G1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-G1110 + G1112)*(-a1110 + a1112)/pow(dphi, 2))*pow(sin(F1111), 2)*pow(sin(a1111), 2)/pow(dtheta, 2)) - l_1*((1.0/2.0)*(-a1101 + a1121)*(l_1*(-G1101 + G1121)*(G1101 - 2*G1111 + G1121)/pow(dtheta, 3) - 1.0/4.0*(-G0111 + G2111)*(G0101 - G0121 - G2101 + G2121)/(pow(dt, 2)*dtheta) + (1.0/4.0)*l_1*(-G1011 + G1211)*(G1001 - G1021 - G1201 + G1221)/(pow(dr, 2)*dtheta) + (1.0/4.0)*l_2*(-G1110 + G1112)*(G1100 - G1102 - G1120 + G1122)/(pow(dphi, 2)*dtheta))*pow(sin(F1111), 2)*pow(sin(a1111), 2)/dtheta + (1.0/2.0)*(-F1101 + F1121)*(-a1101 + a1121)*((1.0/4.0)*l_1*pow(-G1101 + G1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-G0111 + G2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-G1011 + G1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-G1110 + G1112, 2)/pow(dphi, 2))*sin(F1111)*pow(sin(a1111), 2)*cos(F1111)/pow(dtheta, 2) + (1.0/2.0)*pow(-a1101 + a1121, 2)*((1.0/4.0)*l_1*pow(-G1101 + G1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-G0111 + G2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-G1011 + G1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-G1110 + G1112, 2)/pow(dphi, 2))*pow(sin(F1111), 2)*sin(a1111)*cos(a1111)/pow(dtheta, 2) + (a1101 - 2*a1111 + a1121)*((1.0/4.0)*l_1*pow(-G1101 + G1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-G0111 + G2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-G1011 + G1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-G1110 + G1112, 2)/pow(dphi, 2))*pow(sin(F1111), 2)*pow(sin(a1111), 2)/pow(dtheta, 2)) + l_2*((1.0/2.0)*(-F1110 + F1112)*((1.0/8.0)*l_1*(-F1101 + F1121)*(a1100 - a1102 - a1120 + a1122)/(dphi*pow(dtheta, 2)) + (1.0/8.0)*l_1*(-a1101 + a1121)*(F1100 - F1102 - F1120 + F1122)/(dphi*pow(dtheta, 2)) - 1.0/8.0*(-F0111 + F2111)*(a0110 - a0112 - a2110 + a2112)/(dphi*pow(dt, 2)) - 1.0/8.0*(-a0111 + a2111)*(F0110 - F0112 - F2110 + F2112)/(dphi*pow(dt, 2)) + (1.0/8.0)*l_1*(-F1011 + F1211)*(a1010 - a1012 - a1210 + a1212)/(dphi*pow(dr, 2)) + (1.0/8.0)*l_1*(-a1011 + a1211)*(F1010 - F1012 - F1210 + F1212)/(dphi*pow(dr, 2)) + (1.0/2.0)*l_2*(-F1110 + F1112)*(a1110 - 2*a1111 + a1112)/pow(dphi, 3) + (1.0/2.0)*l_2*(-a1110 + a1112)*(F1110 - 2*F1111 + F1112)/pow(dphi, 3))*pow(sin(a1111), 2)/dphi + (1.0/2.0)*(-F1110 + F1112)*(-a1110 + a1112)*((1.0/4.0)*l_1*(-F1101 + F1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-F0111 + F2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-F1011 + F1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-F1110 + F1112)*(-a1110 + a1112)/pow(dphi, 2))*sin(a1111)*cos(a1111)/pow(dphi, 2) + (F1110 - 2*F1111 + F1112)*((1.0/4.0)*l_1*(-F1101 + F1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-F0111 + F2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-F1011 + F1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-F1110 + F1112)*(-a1110 + a1112)/pow(dphi, 2))*pow(sin(a1111), 2)/pow(dphi, 2)) - l_2*((1.0/2.0)*(-a1110 + a1112)*((1.0/4.0)*l_1*(-F1101 + F1121)*(F1100 - F1102 - F1120 + F1122)/(dphi*pow(dtheta, 2)) - 1.0/4.0*(-F0111 + F2111)*(F0110 - F0112 - F2110 + F2112)/(dphi*pow(dt, 2)) + (1.0/4.0)*l_1*(-F1011 + F1211)*(F1010 - F1012 - F1210 + F1212)/(dphi*pow(dr, 2)) + l_2*(-F1110 + F1112)*(F1110 - 2*F1111 + F1112)/pow(dphi, 3))*pow(sin(a1111), 2)/dphi + (1.0/2.0)*pow(-a1110 + a1112, 2)*((1.0/4.0)*l_1*pow(-F1101 + F1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-F0111 + F2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-F1011 + F1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-F1110 + F1112, 2)/pow(dphi, 2))*sin(a1111)*cos(a1111)/pow(dphi, 2) + (a1110 - 2*a1111 + a1112)*((1.0/4.0)*l_1*pow(-F1101 + F1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-F0111 + F2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-F1011 + F1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-F1110 + F1112, 2)/pow(dphi, 2))*pow(sin(a1111), 2)/pow(dphi, 2)) + l_2*((1.0/2.0)*(-G1110 + G1112)*((1.0/8.0)*l_1*(-G1101 + G1121)*(a1100 - a1102 - a1120 + a1122)/(dphi*pow(dtheta, 2)) + (1.0/8.0)*l_1*(-a1101 + a1121)*(G1100 - G1102 - G1120 + G1122)/(dphi*pow(dtheta, 2)) - 1.0/8.0*(-G0111 + G2111)*(a0110 - a0112 - a2110 + a2112)/(dphi*pow(dt, 2)) - 1.0/8.0*(-a0111 + a2111)*(G0110 - G0112 - G2110 + G2112)/(dphi*pow(dt, 2)) + (1.0/8.0)*l_1*(-G1011 + G1211)*(a1010 - a1012 - a1210 + a1212)/(dphi*pow(dr, 2)) + (1.0/8.0)*l_1*(-a1011 + a1211)*(G1010 - G1012 - G1210 + G1212)/(dphi*pow(dr, 2)) + (1.0/2.0)*l_2*(-G1110 + G1112)*(a1110 - 2*a1111 + a1112)/pow(dphi, 3) + (1.0/2.0)*l_2*(-a1110 + a1112)*(G1110 - 2*G1111 + G1112)/pow(dphi, 3))*pow(sin(F1111), 2)*pow(sin(a1111), 2)/dphi + (1.0/2.0)*(-F1110 + F1112)*(-G1110 + G1112)*((1.0/4.0)*l_1*(-G1101 + G1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-G0111 + G2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-G1011 + G1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-G1110 + G1112)*(-a1110 + a1112)/pow(dphi, 2))*sin(F1111)*pow(sin(a1111), 2)*cos(F1111)/pow(dphi, 2) + (1.0/2.0)*(-G1110 + G1112)*(-a1110 + a1112)*((1.0/4.0)*l_1*(-G1101 + G1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-G0111 + G2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-G1011 + G1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-G1110 + G1112)*(-a1110 + a1112)/pow(dphi, 2))*pow(sin(F1111), 2)*sin(a1111)*cos(a1111)/pow(dphi, 2) + (G1110 - 2*G1111 + G1112)*((1.0/4.0)*l_1*(-G1101 + G1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-G0111 + G2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-G1011 + G1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-G1110 + G1112)*(-a1110 + a1112)/pow(dphi, 2))*pow(sin(F1111), 2)*pow(sin(a1111), 2)/pow(dphi, 2)) - l_2*((1.0/2.0)*(-a1110 + a1112)*((1.0/4.0)*l_1*(-G1101 + G1121)*(G1100 - G1102 - G1120 + G1122)/(dphi*pow(dtheta, 2)) - 1.0/4.0*(-G0111 + G2111)*(G0110 - G0112 - G2110 + G2112)/(dphi*pow(dt, 2)) + (1.0/4.0)*l_1*(-G1011 + G1211)*(G1010 - G1012 - G1210 + G1212)/(dphi*pow(dr, 2)) + l_2*(-G1110 + G1112)*(G1110 - 2*G1111 + G1112)/pow(dphi, 3))*pow(sin(F1111), 2)*pow(sin(a1111), 2)/dphi + (1.0/2.0)*(-F1110 + F1112)*(-a1110 + a1112)*((1.0/4.0)*l_1*pow(-G1101 + G1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-G0111 + G2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-G1011 + G1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-G1110 + G1112, 2)/pow(dphi, 2))*sin(F1111)*pow(sin(a1111), 2)*cos(F1111)/pow(dphi, 2) + (1.0/2.0)*pow(-a1110 + a1112, 2)*((1.0/4.0)*l_1*pow(-G1101 + G1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-G0111 + G2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-G1011 + G1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-G1110 + G1112, 2)/pow(dphi, 2))*pow(sin(F1111), 2)*sin(a1111)*cos(a1111)/pow(dphi, 2) + (a1110 - 2*a1111 + a1112)*((1.0/4.0)*l_1*pow(-G1101 + G1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-G0111 + G2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-G1011 + G1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-G1110 + G1112, 2)/pow(dphi, 2))*pow(sin(F1111), 2)*pow(sin(a1111), 2)/pow(dphi, 2)) + 2*(((1.0/4.0)*l_1*pow(-F1101 + F1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-F0111 + F2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-F1011 + F1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-F1110 + F1112, 2)/pow(dphi, 2))*((1.0/4.0)*l_1*pow(-G1101 + G1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-G0111 + G2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-G1011 + G1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-G1110 + G1112, 2)/pow(dphi, 2)) - pow((1.0/4.0)*l_1*(-F1101 + F1121)*(-G1101 + G1121)/pow(dtheta, 2) - 1.0/4.0*(-F0111 + F2111)*(-G0111 + G2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-F1011 + F1211)*(-G1011 + G1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-F1110 + F1112)*(-G1110 + G1112)/pow(dphi, 2), 2))*pow(sin(F1111), 2)*pow(sin(a1111), 3)*cos(a1111) + (((1.0/4.0)*l_1*pow(-F1101 + F1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-F0111 + F2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-F1011 + F1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-F1110 + F1112, 2)/pow(dphi, 2))*((1.0/4.0)*l_1*pow(-a1101 + a1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-a0111 + a2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-a1011 + a1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-a1110 + a1112, 2)/pow(dphi, 2)) - pow((1.0/4.0)*l_1*(-F1101 + F1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-F0111 + F2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-F1011 + F1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-F1110 + F1112)*(-a1110 + a1112)/pow(dphi, 2), 2))*sin(a1111)*cos(a1111) + (((1.0/4.0)*l_1*pow(-G1101 + G1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-G0111 + G2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-G1011 + G1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-G1110 + G1112, 2)/pow(dphi, 2))*((1.0/4.0)*l_1*pow(-a1101 + a1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-a0111 + a2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-a1011 + a1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-a1110 + a1112, 2)/pow(dphi, 2)) - pow((1.0/4.0)*l_1*(-G1101 + G1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-G0111 + G2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-G1011 + G1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-G1110 + G1112)*(-a1110 + a1112)/pow(dphi, 2), 2))*pow(sin(F1111), 2)*sin(a1111)*cos(a1111) - 1.0/2.0*(-F0111 + F2111)*((1.0/8.0)*l_1*(-F1101 + F1121)*(a0101 - a0121 - a2101 + a2121)/(dt*pow(dtheta, 2)) + (1.0/8.0)*l_1*(-a1101 + a1121)*(F0101 - F0121 - F2101 + F2121)/(dt*pow(dtheta, 2)) - 1.0/2.0*(-F0111 + F2111)*(a0111 - 2*a1111 + a2111)/pow(dt, 3) - 1.0/2.0*(-a0111 + a2111)*(F0111 - 2*F1111 + F2111)/pow(dt, 3) + (1.0/8.0)*l_1*(-F1011 + F1211)*(a0011 - a0211 - a2011 + a2211)/(pow(dr, 2)*dt) + (1.0/8.0)*l_1*(-a1011 + a1211)*(F0011 - F0211 - F2011 + F2211)/(pow(dr, 2)*dt) + (1.0/8.0)*l_2*(-F1110 + F1112)*(a0110 - a0112 - a2110 + a2112)/(pow(dphi, 2)*dt) + (1.0/8.0)*l_2*(-a1110 + a1112)*(F0110 - F0112 - F2110 + F2112)/(pow(dphi, 2)*dt))*pow(sin(a1111), 2)/dt - 1.0/2.0*(-G0111 + G2111)*((1.0/8.0)*l_1*(-G1101 + G1121)*(a0101 - a0121 - a2101 + a2121)/(dt*pow(dtheta, 2)) + (1.0/8.0)*l_1*(-a1101 + a1121)*(G0101 - G0121 - G2101 + G2121)/(dt*pow(dtheta, 2)) - 1.0/2.0*(-G0111 + G2111)*(a0111 - 2*a1111 + a2111)/pow(dt, 3) - 1.0/2.0*(-a0111 + a2111)*(G0111 - 2*G1111 + G2111)/pow(dt, 3) + (1.0/8.0)*l_1*(-G1011 + G1211)*(a0011 - a0211 - a2011 + a2211)/(pow(dr, 2)*dt) + (1.0/8.0)*l_1*(-a1011 + a1211)*(G0011 - G0211 - G2011 + G2211)/(pow(dr, 2)*dt) + (1.0/8.0)*l_2*(-G1110 + G1112)*(a0110 - a0112 - a2110 + a2112)/(pow(dphi, 2)*dt) + (1.0/8.0)*l_2*(-a1110 + a1112)*(G0110 - G0112 - G2110 + G2112)/(pow(dphi, 2)*dt))*pow(sin(F1111), 2)*pow(sin(a1111), 2)/dt + (1.0/2.0)*(-a0111 + a2111)*((1.0/4.0)*l_1*(-F1101 + F1121)*(F0101 - F0121 - F2101 + F2121)/(dt*pow(dtheta, 2)) - (-F0111 + F2111)*(F0111 - 2*F1111 + F2111)/pow(dt, 3) + (1.0/4.0)*l_1*(-F1011 + F1211)*(F0011 - F0211 - F2011 + F2211)/(pow(dr, 2)*dt) + (1.0/4.0)*l_2*(-F1110 + F1112)*(F0110 - F0112 - F2110 + F2112)/(pow(dphi, 2)*dt))*pow(sin(a1111), 2)/dt + (1.0/2.0)*(-a0111 + a2111)*((1.0/4.0)*l_1*(-G1101 + G1121)*(G0101 - G0121 - G2101 + G2121)/(dt*pow(dtheta, 2)) - (-G0111 + G2111)*(G0111 - 2*G1111 + G2111)/pow(dt, 3) + (1.0/4.0)*l_1*(-G1011 + G1211)*(G0011 - G0211 - G2011 + G2211)/(pow(dr, 2)*dt) + (1.0/4.0)*l_2*(-G1110 + G1112)*(G0110 - G0112 - G2110 + G2112)/(pow(dphi, 2)*dt))*pow(sin(F1111), 2)*pow(sin(a1111), 2)/dt - 1.0/2.0*(-F0111 + F2111)*(-G0111 + G2111)*((1.0/4.0)*l_1*(-G1101 + G1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-G0111 + G2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-G1011 + G1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-G1110 + G1112)*(-a1110 + a1112)/pow(dphi, 2))*sin(F1111)*pow(sin(a1111), 2)*cos(F1111)/pow(dt, 2) + (1.0/2.0)*(-F0111 + F2111)*(-a0111 + a2111)*((1.0/4.0)*l_1*pow(-G1101 + G1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-G0111 + G2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-G1011 + G1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-G1110 + G1112, 2)/pow(dphi, 2))*sin(F1111)*pow(sin(a1111), 2)*cos(F1111)/pow(dt, 2) - 1.0/2.0*(-F0111 + F2111)*(-a0111 + a2111)*((1.0/4.0)*l_1*(-F1101 + F1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-F0111 + F2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-F1011 + F1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-F1110 + F1112)*(-a1110 + a1112)/pow(dphi, 2))*sin(a1111)*cos(a1111)/pow(dt, 2) - 1.0/2.0*(-G0111 + G2111)*(-a0111 + a2111)*((1.0/4.0)*l_1*(-G1101 + G1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-G0111 + G2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-G1011 + G1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-G1110 + G1112)*(-a1110 + a1112)/pow(dphi, 2))*pow(sin(F1111), 2)*sin(a1111)*cos(a1111)/pow(dt, 2) + (1.0/2.0)*pow(-a0111 + a2111, 2)*((1.0/4.0)*l_1*pow(-F1101 + F1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-F0111 + F2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-F1011 + F1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-F1110 + F1112, 2)/pow(dphi, 2))*sin(a1111)*cos(a1111)/pow(dt, 2) + (1.0/2.0)*pow(-a0111 + a2111, 2)*((1.0/4.0)*l_1*pow(-G1101 + G1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-G0111 + G2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-G1011 + G1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-G1110 + G1112, 2)/pow(dphi, 2))*pow(sin(F1111), 2)*sin(a1111)*cos(a1111)/pow(dt, 2) - (F0111 - 2*F1111 + F2111)*((1.0/4.0)*l_1*(-F1101 + F1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-F0111 + F2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-F1011 + F1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-F1110 + F1112)*(-a1110 + a1112)/pow(dphi, 2))*pow(sin(a1111), 2)/pow(dt, 2) - (G0111 - 2*G1111 + G2111)*((1.0/4.0)*l_1*(-G1101 + G1121)*(-a1101 + a1121)/pow(dtheta, 2) - 1.0/4.0*(-G0111 + G2111)*(-a0111 + a2111)/pow(dt, 2) + (1.0/4.0)*l_1*(-G1011 + G1211)*(-a1011 + a1211)/pow(dr, 2) + (1.0/4.0)*l_2*(-G1110 + G1112)*(-a1110 + a1112)/pow(dphi, 2))*pow(sin(F1111), 2)*pow(sin(a1111), 2)/pow(dt, 2) + (a0111 - 2*a1111 + a2111)*((1.0/4.0)*l_1*pow(-F1101 + F1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-F0111 + F2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-F1011 + F1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-F1110 + F1112, 2)/pow(dphi, 2))*pow(sin(a1111), 2)/pow(dt, 2) + (a0111 - 2*a1111 + a2111)*((1.0/4.0)*l_1*pow(-G1101 + G1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-G0111 + G2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-G1011 + G1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-G1110 + G1112, 2)/pow(dphi, 2))*pow(sin(F1111), 2)*pow(sin(a1111), 2)/pow(dt, 2)) + (((1.0/4.0)*l_1*pow(-G1101 + G1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-G0111 + G2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-G1011 + G1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-G1110 + G1112, 2)/pow(dphi, 2))*pow(sin(F1111), 2) + (1.0/4.0)*l_1*pow(-F1101 + F1121, 2)/pow(dtheta, 2) - 1.0/4.0*pow(-F0111 + F2111, 2)/pow(dt, 2) + (1.0/4.0)*l_1*pow(-F1011 + F1211, 2)/pow(dr, 2) + (1.0/4.0)*l_2*pow(-F1110 + F1112, 2)/pow(dphi, 2))*sin(a1111)*cos(a1111) + l_1*(a1101 - 2*a1111 + a1121)/pow(dtheta, 2) - (a0111 - 2*a1111 + a2111)/pow(dt, 2) + l_1*(a1011 - 2*a1111 + a1211)/pow(dr, 2) + l_2*(a1110 - 2*a1111 + a1112)/pow(dphi, 2)

# %%
solve(eq, a2111)
# Out:
# [a2111 == 1/2*(16*dphi^2*dr^2*dtheta^2 + (2*(G0111*G1110*sin(F1111)^2 - G0111*G1112*sin(F1111)^2 + F0111*F1110 - F0111*F1112 - (F1110 - F1112)*F2111 - (G1110*sin(F1111)^2 - G1112*sin(F1111)^2)*G2111)*L*a1112*cos(a1111)*sin(a1111) + (8*G0111*G1111*sin(F1111)^2 + 2*(F0111*cos(F1111)*sin(F1111) - F2111*cos(F1111)*sin(F1111) - 2*sin(F1111)^2)*G1110^2 + 2*(F0111*cos(F1111)*sin(F1111) - F2111*cos(F1111)*sin(F1111) - 2*sin(F1111)^2)*G1112^2 + (F0110 - 4*F0111 - F0112)*F1110 - 4*F1110^2 + 8*F0111*F1111 - (F0110 + 4*F0111 - F0112 - 8*F1110)*F1112 - 4*F1112^2 - (F1110 - F1112)*F2110 + 4*(F1110 - 2*F1111 + F1112)*F2111 + (F1110 - F1112)*F2112 + (G0110*sin(F1111)^2 - G0112*sin(F1111)^2 - 2*(F1110*cos(F1111)*sin(F1111) - F1112*cos(F1111)*sin(F1111) + 2*sin(F1111)^2)*G0111)*G1110 - (G0110*sin(F1111)^2 - G0112*sin(F1111)^2 - 2*(F1110*cos(F1111)*sin(F1111) - F1112*cos(F1111)*sin(F1111) - 2*sin(F1111)^2)*G0111 + 4*(F0111*cos(F1111)*sin(F1111) - F2111*cos(F1111)*sin(F1111) - 2*sin(F1111)^2)*G1110)*G11
# ...
